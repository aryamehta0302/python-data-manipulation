# %% [markdown]
# # 📊 Salary Data Analysis (2025) — Comprehensive Report
#
# This notebook presents a detailed analysis of the salary dataset provided. The goal is to extract meaningful insights and trends based on job title, experience, company location, and more.
#
# ---
#
# ## 🔍 Step 1: Importing Libraries
#
# We begin by importing the necessary libraries.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set(style='whitegrid')

# %% [markdown]
# ## 📥 Step 2: Loading the Dataset

# %%
df = pd.read_csv("salaries.csv")
df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2025               MI              FT             Data Scientist
# 1       2025               MI              FT             Data Scientist
# 2       2025               SE              FT       Data Product Manager
# 3       2025               SE              FT       Data Product Manager
# 4       2025               SE              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  132600             USD         132600                 US           100
# 1  102000             USD         102000                 US           100
# 2  260520             USD         260520                 US             0
# 3  140280             USD         140280                 US             0
# 4  215000             USD         215000                 US             0
#
#   company_location company_size
# 0               US            M
# ...

# %% [markdown]
# ## 🧾 Step 3: Data Overview

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136757 entries, 0 to 136756
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           136757 non-null  int64
#  1   experience_level    136757 non-null  object
#  2   employment_type     136757 non-null  object
#  3   job_title           136757 non-null  object
#  4   salary              136757 non-null  int64
#  5   salary_currency     136757 non-null  object
#  6   salary_in_usd       136757 non-null  int64
#  7   employee_residence  136757 non-null  object
#  8   remote_ratio        136757 non-null  int64
#  9   company_location    136757 non-null  object
#  10  company_size        136757 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 11.5+ MB

# %% [markdown]
# ## 🔍 Step 4: Checking for Missing Values

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# ## 📊 Step 5: Summary Statistics

# %%
df.describe(include='all')
# Out:
#             work_year experience_level employment_type       job_title  \
# count   136757.000000           136757          136757          136757
# unique            NaN                4               4             398
# top               NaN               SE              FT  Data Scientist
# freq              NaN            79164          135955           17574
# mean      2024.374686              NaN             NaN             NaN
# std          0.679644              NaN             NaN             NaN
# min       2020.000000              NaN             NaN             NaN
# 25%       2024.000000              NaN             NaN             NaN
# 50%       2024.000000              NaN             NaN             NaN
# 75%       2025.000000              NaN             NaN             NaN
# max       2025.000000              NaN             NaN             NaN
#
#               salary salary_currency  salary_in_usd employee_residence  \
# ...

# %% [markdown]
# ## 💵 Step 6: Salary Distribution (USD)

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['salary_in_usd'], bins=50, kde=True)
plt.title('Salary Distribution in USD')
plt.xlabel('Salary (USD)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 📈 Step 7: Average Salary by Experience Level

# %%
exp_salary = df.groupby("experience_level")["salary_in_usd"].mean().sort_values()
plt.figure(figsize=(8,4))
sns.barplot(x=exp_salary.index, y=exp_salary.values, palette="viridis")
plt.title("Average Salary by Experience Level")
plt.ylabel("Average Salary (USD)")
plt.xlabel("Experience Level")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24984\1950711935.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=exp_salary.index, y=exp_salary.values, palette="viridis")

# %% [markdown]
# ## 🧑‍💼 Step 8: Top Paying Job Titles

# %%
top_jobs = df.groupby("job_title")["salary_in_usd"].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(12,6))
sns.barplot(x=top_jobs.values, y=top_jobs.index, palette="mako")
plt.title("Top 10 Highest Paying Job Titles")
plt.xlabel("Average Salary (USD)")
plt.ylabel("Job Title")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24984\681748290.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_jobs.values, y=top_jobs.index, palette="mako")

# %% [markdown]
# ## 🏠 Step 9: Remote Work and Salary

# %%
remote_avg_salary = df.groupby("remote_ratio")["salary_in_usd"].mean()
plt.figure(figsize=(7,4))
sns.barplot(x=remote_avg_salary.index.astype(str), y=remote_avg_salary.values, palette="coolwarm")
plt.title("Average Salary by Remote Work Ratio")
plt.xlabel("Remote Work %")
plt.ylabel("Average Salary (USD)")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24984\2136112643.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=remote_avg_salary.index.astype(str), y=remote_avg_salary.values, palette="coolwarm")

# %% [markdown]
# ## 🌍 Step 10: Company Location vs Salary

# %%
top_locations = df.groupby("company_location")["salary_in_usd"].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(10,5))
sns.barplot(x=top_locations.index, y=top_locations.values, palette="cubehelix")
plt.title("Top Paying Company Locations")
plt.xlabel("Company Location")
plt.ylabel("Average Salary (USD)")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24984\4189364314.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_locations.index, y=top_locations.values, palette="cubehelix")

# %% [markdown]
# ## 📌 Final Observations and Conclusion
#
# - 👨‍🔬 Senior-level professionals earn the highest average salary, followed by mid-level.
# - 💼 Certain job roles like **Data Architect** and **ML Engineer** offer significantly higher pay.
# - 🏠 Remote jobs (100% remote) show competitive salaries and are becoming more common.
# - 🌎 Company location plays a vital role—companies based in certain countries like the US offer higher average salaries.
#
# ### ✅ Conclusion:
# This analysis highlights the importance of experience, remote work flexibility, and job specialization in determining salary. Job seekers can align their goals accordingly to maximize earnings potential.
